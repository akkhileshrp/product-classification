# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !python "D:/DCMC_Project/yolov5/detect.py" --weights "D:/DCMC_Project/yolov5/b_est.pt" --img 640 --conf 0.25 --source https://100.65.109.247:8080/video
import cv2
if(cv2.waitKey == 'q'):
    break
# Out:
# detect: weights=['D:/DCMC_Project/yolov5/b_est.pt'], source=https://100.65.109.247:8080/video, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-187-g0004c74 Python-3.11.3 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: https://100.65.109.247:8080/video...  Success (inf frames 1920x1080 at 25.00 FPS)
#
# 0: 384x640 (no detections), 240.1ms
# 0: 384x640 (no detections), 228.7ms
# 0: 384x640 (no detections), 182.4ms
# 0: 384x640 (no detections), 195.6ms
# 0: 384x640 (no detections), 181.2ms
# 0: 384x640 (no detections), 175.6ms
# ...
